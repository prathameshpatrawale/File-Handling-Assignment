# %% [markdown]
# 1. What is the difference between interpreted and compiled languages?
# - Interpreted languages are exeecuted line by line at runtime by an interpreter, while compiled languages are translated into mahcine code by a compiler before execution.
#
# 2. What is exception handling in Python?
# - Exception handling in python is a mechanism to handle runtime errors using try, except, finally blocks it allows the program to continue execution if an error occurs.
#
# 3. What is the purpose of the finally block in exception handling?
# - finally block is used to execute a block of code regardless of whether an exception was raised or not. It is typically used for cleanup actions, such as closing files or releasing resources.
#
# 4. What is logging in Python?
# - Login in Python is a way to track events that happenswhen the software runs it is used for debuggingand monitoring purposesPython provides inbuilt login module that allowsdeveloper to log message at different security level such asdebug, info, warning, error, critical
#
# 5. What is the significance of the __del__ method in Python?
# - The__del__ Methods is destructor in Python it is called when an object is about to be destroyed space it is used to perform cleanup action spaces such as closing file or releasing resources.
#
# 6. What is the difference between import and from ... import in Python?
# - Import statement imports the entire module while from... Import statement imports the specific attribute for functions and classes from module It allows you to use imported attribute directly without prefixing with model name
#
# 7. How can you handle multiple exceptions in Python?
# - we can handle multiple exceptions in python using multiple except block Or we can also use tuple to catch multiple exception types in a single except block
#
# 8. What is the purpose of the with statement when handling files in Python?
# - with statement is used to wrap the execution of a block of code within methods defined by Context manager it is used to open files and automatically close them after the block of code is executed
#
# 9. What is the difference between multithreading and multiprocessing?
# - Multithreading is a technique where multiple threads run concurrently within a single process sharing the same memory space while multiprocessing is a technique where multiple processors run independently each with its own memory. It is used to take advantage of multiple CPU cores for parallel processing.
#
# 10. What are the advantages of using logging in a program?
# - The advantages of using logging in a program include:
# - Debugging: Helps identify issues and track the flow of execution.
# - Monitoring: Provides insights into the application's performance and behavior.
# - Error tracking: Captures errors and exceptions for analysis.
# - Configurability: Allows different logging levels (e.g., debug, info, warning, error) to control the verbosity of logs.
# - Persistence: Logs can be saved to files or external systems for later review.
#
# 11. What is memory management in Python?
# -  the process of allocating and freeing memory during program execution. Python manages memory automatically using a private heap, garbage collection, and memory pooling.
#
# 12. What are the basic steps involved in exception handling in Python?
# - Try: Wrap the code that may cause an error in a try block.
# - Except: Handle the error using one or more except blocks.
# - Else (optional): Runs if no exception occurs.
# - Finally (optional): Runs code regardless of whether an exception occurred.
#
# 13. Why is memory management important in Python?
# - Avoid memory leaks (wasting memory on unused data)
# - Improve performance (faster and smoother programs)
# - Ensure efficient resource use (especially with large data or long-running apps)
#
# 14. What is the role of try and except in exception handling?
# - The try block is used to run code that might cause an error, and the except block is used to handle the error if it happens.
#
# 15. How does Python's garbage collection system work?
# - Python deletes unused objects automatically using reference counting and a cyclic garbage collector.
#
# 16. What is the purpose of the else block in exception handling?
# - The else block in exception handling runs only if no exception occurs in the try block It’s used to write code that should run only when no error happens
#
# 17. What are the common logging levels in Python?
# - The common logging levels in Python are:
# - DEBUG: Detailed information for diagnosing problems.
# - INFO: General information about the program's execution.
# - WARNING: Indicates a potential issue that may not be an error.
# - ERROR: An error occurred that prevented a function from executing.
# - CRITICAL: A serious error that may prevent the program from continuing.
#
# 18. What is the difference between os.fork() and multiprocessing in Python?
# - os.fork() creates a new process by duplicating the current process, while the multiprocessing module provides a higher-level interface for creating and managing multiple processes, allowing for easier communication and synchronization between them.
#
# 19. What is the importance of closing a file in Python?
# - Closing a file in Python is important to free up system resources, ensure that all data is written to the file, and prevent data corruption. It also helps avoid memory leaks and ensures that file handles are properly released.
#
# 20. What is the difference between file.read() and file.readline() in Python?
# - file.read() reads the entire content of a file as a single string, while file.readline() reads the next line from the file each time it is called. The former is used for accessing the whole file at once, and the latter is useful for reading the file line-by-line.
#
# 21. What is the logging module in Python used for?
# - The logging module in Python is used for tracking events and errors in a program by recording log messages. It allows developers to log messages at different severity levels (e.g., DEBUG, INFO, WARNING, ERROR, CRITICAL) and output them to various destinations like the console or a file for debugging and monitoring purposes.
#
# 22. What is the os module in Python used for in file handling?
# - The os module in Python is used for interacting with the operating system, including tasks like navigating the file system, creating or removing directories, and manipulating file paths. In file handling, it helps with operations like checking if a file exists, renaming files, or getting file properties (e.g., size or permissions).
#
# 23. What are the challenges associated with memory management in Python?
# - Some challenges associated with memory management in Python include:
# - Memory leaks: Unused objects may not be released, leading to increased memory usage.
# - Fragmentation: Memory can become fragmented over time, making it harder to allocate large blocks of memory.
# - Performance: Inefficient memory management can slow down the program, especially with large datasets or long-running applications.
# - Reference cycles: Circular references can prevent garbage collection from freeing memory, requiring manual intervention.
#
# 24. How do you raise an exception manually in Python?
# - You can raise an exception manually in Python using the raise statement followed by the exception type and an optional error message.
#
# 25. Why is it important to use multithreading in certain applications?
# - Multithreading is important in certain applications to improve performance by allowing concurrent execution of tasks, making better use of CPU resources, and enhancing responsiveness in applications that require real-time processing or user interaction. It is particularly useful for I/O-bound tasks, such as network communication or file operations, where waiting for external resources can be time-consuming.

# %% [markdown]
# ## Practical Questions

# %%
# 1. How can you open a file for writing in Python and write a string to it?

# for creating file using with and for open in write mode use 'w'
with open('Example.txt', 'w') as f:
    f.write("Hi Friends!, my name is Prathamesh.") # this is for writing content in file

# %%
# 2. Write a Python program to read the contents of a file and print each line.

# opening file in 'r' means read mode
with open("Example.txt", 'r') as f:
    print(f.readlines()) # f.read to read file and print for printing it.
# Out:
# Hi Friends!, my name is Prathamesh.

# %%
# 3. How would you handle a case where the file doesn't exist while trying to open it for reading?

# file handling using try - except block
try:
    with open('file.txt','r') as f:
        print(f.read())

# for file not found error
except FileNotFoundError as fe:
    print("File not found, error: ", fe)

# For other exceptions(not needed for question)
except Exception as e:
    print("Something went wrong... Error: ", e)

# this will print always
finally:
    print("This will handle the exception for file not found")
# Out:
# File not found, error:  [Errno 2] No such file or directory: 'file.txt'
# This will handle the exception for file not found

# %%
# 4. Write a Python script that reads from one file and writes its content to another file.

# 1st open content file in read mode
f = open("Example.txt", 'r') 
content = f.read() # assign its content to variable named content
f.close() # file close

# open/Create 2nd file in write mode 
f = open('Example1.txt','w')
f.write(content) # write the content from previous file
f.close() # file close

# %%
# 5. How would you catch and handle division by zero error in Python?

# Taking input from user to calculate division
num1 = int(input("Enter first number: "))
num2 = int(input("Enter Second number: "))

# using try block to catch if error occurs
try: 
    calc = num1 / num2
    print(f"The divsion of {num1} and {num2} is : {calc}")

# specific exception if num1 / zero this will raise error
except ZeroDivisionError as zde:
    print(f"The Division by zero is not possible : {zde}")

# this is generic exception for unknown error
except Exception as e:
    print("Something went wrong... : ", e)
# Out:
# The Division by zero is not possible and error is division by zero

# %%
# 6. Write a Python program that logs an error message to a log file when a division by zero exception occurs.

# importing logging module
import logging
logging.basicConfig(filename="log1.log",filemode='a',level=logging.DEBUG ,
                    format=('%(asctime)s - %(levelname)s - %(message)s'))

# defining function for division
def calc(a,b):
    logging.info(f"This are values {a} and {b}")
    if b == 0:
        logging.error(f"The value of b can not be zero")
    else:
        result = a / b
        logging.info(f"The function works fine result : {result}")

calc(1,0)
calc(100,2)
logging.shutdown()

# %%
# 7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module.

# import logging module
import logging
# doing basic configuration
logging.basicConfig(filename="log2.log",filemode='a',level=logging.DEBUG ,
                    format=('%(asctime)s - %(levelname)s - %(message)s'))

logging.info("This is logging Information.") # this is for info

logging.error("This is Error massage ") # genrally this is shown error in code

logging.warning("This is Warning massage show ") # generally it gives warnings

# %%
# 8. Write a program to handle a file opening error using exception handling.
    
try:
    with open("file.15",'r') as f:
        f.write("Hello World")

# this block execute if file not found
except FileNotFoundError as fe:
    print("File not found: ", fe)

# This block will execute if any other error foound
except Exception as e:
    print("Something went wrong... : ", e)
# Out:
# File not found:  [Errno 2] No such file or directory: 'file.15'

# %%
# 9. How can you read a file line by line and store its content in a list in Python?

# no mode given means read mod and readlines read all lines and strored in list
with open("Example.txt") as f:
    print(f.readlines())
# Out:
# ['Hi Friends!, my name is Prathamesh.\n', 'I am a data SCience student,\n', 'I will wants to become data scientiest.\n', 'I am pursuing my education with \n', 'PW Skills']

# %%
# 10. How can you append data to an existing file in Python?

# a mode means append mode 
with open("Example.txt",'a') as f:
    f.write("\nThis line append last to the previous file")

# %%
# 11. Write a Python program that uses a try-except block to handle an error when attempting to access a 
# dictionary key that doesn't exist

dict = {"Name": "Charlie","Age":30,"City":"Pune"}

# trying to catch error if key not exist.
try:
    print(dict["Email"])

# print key not found if key-error occurs
except KeyError as k:
    print("The Key not found Error:",k)
# Out:
# Charlie

# %%
# 12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions?


# using try block to catch if error occurs
try: 
    # Taking input from user to calculate division
    num1 = int(input("Enter first number: "))
    num2 = int(input("Enter Second number: "))

    calc = num1 / num2
    print(f"The divsion of {num1} and {num2} is : {calc}")

# if num1 divided by zero
except ZeroDivisionError as zde:
    print(f"The Division by zero is not possible : {zde}")

# if string is provided
except ValueError as ve:
    print("Please Enter a valid number Error: ",ve)

# this is generic exception for unknown error
except Exception as e:
    print("Something went wrong... Error: ", e)
# Out:
# Please Enter a valid number Error:  invalid literal for int() with base 10: '1j'

# %%
# 13. How would you check if a file exists before attempting to read it in Python?

# simple way to check file exist or not
import os
a = os.path.exists("fil e.txt")
print("The file exist is: ",a) 

# onother way is

# trying to cheack file found or not
try:
    f = open("fil e.txt","r")

# this exception tells that file exist or not
except FileNotFoundError as fe:
    print("Please check the File name, \nFile not found Error:", fe)

# if file open then read and close it
else:
    a = f.read()
    print(a)
    f.close()
# Out:
# The file exist is:  False
# Please check the File name,
# File not found Error: [Errno 2] No such file or directory: 'fil e.txt'

# %%
# 14. Write a program that uses the logging module to log both informational and error messages

import logging
# doing basic configuration
logging.basicConfig(filename="log4.log",filemode='a',level=logging.DEBUG ,
                    format=('%(asctime)s - %(levelname)s - %(message)s'))

# giving information about proces started
logging.info("This is simple addition started")
a = 45 
b = '54'
try:
    c = a+b
except TypeError as te:
    logging.error(f"Value error occurs for a= {a} + b= {b} : {te}") # this shows error

# %%
# 15. Write a Python program that prints the content of a file and handles the case when the file is empty.

# creat function to check file empty or not
def file_check(file):
    if len(file) == 0:
        print("File is Empty")
    else:
        print(file)

with open('file.txt',"r") as f:
    f1 = f.read()
    file_check(f1)
# Out:
# File is Empty

# %%
# 16. Demonstrate how to use memory profiling to check the memory usage of a small program?

# Install memory_profiler
# %pip install memory_profiler

from memory_profiler import memory_usage

# Define a function to compute memory usage
def compute():
    data = [x * 2 for x in range(100000)]  # This line uses memory
    return data

# Use memory_usage to profile the function
mem_usage = memory_usage(proc=compute, interval=0.1, timeout=1)
print("Memory usage during computation:", mem_usage)
# Out:
# Memory usage during computation: [77.0703125, 77.0703125, 77.4375, 78.80078125, 75.96875]

# %%
# 17. Write a Python program to create and write a list of numbers to a file, one number per line.

# creating list using loop
l = []
for i in range (10):
    l.append(i)

# creating new file and appending numbers to the file
with open("num_list.txt",'a') as f:
    for i in l:
        f.write(f"\n{i}")

# %%
# 18. How would you implement a basic logging setup that logs to a file with rotation after 1MB?

import logging
from logging.handlers import RotatingFileHandler

# Create a rotating file handler
log_handler = RotatingFileHandler(
    'app.log',           # Log file name
    maxBytes=1 * 1024 * 1024,  # 1MB size limit
    backupCount=3             # Keep up to 3 old log files (e.g., app.log.1, app.log.2, ...)
)

# Set log format
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
log_handler.setFormatter(formatter)

# Set up root logger
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.addHandler(log_handler)

# Example log messages
for i in range(10000):
    logger.info(f"This is log message number {i}")

# %%
#19. Write a program that handles both IndexError and KeyError using a try-except block?

# we have one list and one dictionary
l = [1,2,3,4,5,6,7,8,9]
dict = {"Name": "Charlie","Age":30,"City":"Pune"}

# trying to catch if error occurs
try:
    print(l[10])
    print(dict["hight"])


except KeyError as ke:
    print("No such key in dictionary, \nKey Not Found Error:",ke)

except IndexError as ie:
    print("No such index in list, \nIndex Not Found Error:",ie)
# Out:
# No such index in list,
# Index Not Found Error: list index out of range

# %%
#20. How would you open a file and read its contents using a context manager in Python?

# opening file
with open("Example.txt",'r') as f:
    print(f.read())
# Out:
# Hi Friends!, my name is Prathamesh.
# I am a data SCience student,
# I will wants to become data scientiest.
# I am pursuing my education with
# PW Skills
# This line append last to the previous file

# %%
# 21. Write a Python program that reads a file and prints the number of occurrences of a specific word.

with open("Example.txt", 'r') as f:
    content = f.read()
    print(content.count("am"))
# Out:
# 2

# %%
# 22. How can you check if a file is empty before attempting to read its contents?

# importing os module to know file size
import os
with open("Example.txt" ,'r') as f:
    a = os.path.getsize("Example.txt")
    if a != 0:
        print(f.read())
    else:
        print("file is empty")
# Out:
# Hi Friends!, my name is Prathamesh.
# I am a data SCience student,
# I will wants to become data scientiest.
# I am pursuing my education with
# PW Skills
# This line append last to the previous file

# %%
# 23. Write a Python program that writes to a log file when an error occurs during file handling

# importing logging module
import logging
logging.basicConfig(filename="log3.log",filemode='a',level=logging.DEBUG ,
                    format=('%(asctime)s - %(levelname)s - %(message)s'))

try:
    f = open('test.txt','r') 
    logging.info("The file is oppening")

except FileNotFoundError as fe:
    logging.error(f"The file not found{fe}")

else:
    logging.info("file opened sucessfully")
    a = f.read()
    logging.info(f"The file is readed: {a}")
    f.close()
    logging.info("file closed sucessfully")
